# %% [markdown]
# <a href="https://colab.research.google.com/github/Anamtasiddiqui/Image_Processing_Using_Pyyton/blob/main/IP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image, ImageFilter, ImageDraw, ImageFont

# %%
img = Image.open('pic1.jpeg')

# %%
img.format
# Out:
# 'JPEG'

# %%
img.mode
# Out:
# 'RGB'

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F60462EDD90>

# %%
img.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=400x400 at 0x7F6045A97890>

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F6045A97CD0>

# %%
img2 = Image.open('pic2.png')

# %%
img2.mode
# Out:
# 'RGBA'

# %%
logo = img2.crop((0, 1200, 1200, 1496))

# %%
logo
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x296 at 0x7F604CAC4210>

# %%
logo.resize((400, 100))
# Out:
# <PIL.Image.Image image mode=RGBA size=400x100 at 0x7F6046308BD0>

# %%
logo.resize((400, 100), resample= Image.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x100 at 0x7F6045A8EF50>

# %%
img.resize((1200, 1200))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7F6045A8EB10>
